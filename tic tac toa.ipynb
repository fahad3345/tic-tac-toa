# %%
''' Implement the Tic tac toe Game on python using List 
first option player 1 vs player 2
player vs CPU 
Your code should be yours no copy from the internet'''
try:
    import random
    import sys
    list2=('1','2','3','4','5','6','7','8','9')
    list1=['X','O']
    dicti={'1':' ','2':' ','3':' ','4':' ','5':' ','6':' ','7':' ','8':' ','9':' '}
    count=0
    a=0
    b=0
    def position(dicti):       #Design of game

        print('  '+dicti['1']+'|'+' '+dicti['2']+'|'+dicti['3'])
        print(' --+--+-- ')
        print('  '+dicti['4']+'|'+' '+dicti['5']+'|'+dicti['6'])
        print(' --+--+-- ')
        print('  '+dicti['7']+'|'+' '+dicti['8']+'|'+dicti['9'])
    def dual():               #The function of Dual play 
        global count
        while count<6:
            position(dicti)
            print(inp1,"'s choice ",list1[0],'.move to which place(numbers in between 1-9):')
            move=input()
            if(dicti[move]==' '):
                dicti[move]=list1[0]
                check()
            else:
                print('this place is already filled\nmove to which place:')
                continue
            while count<5:
                position(dicti)
                print(inp2,"'s choice ",list1[1],'.move to which place(numbers in between 1-9):')
                move=input()
                if(dicti[move]==' '):
                    dicti[move]=list1[1]
                    check()
                else:
                    print('this place is already filled\nmove to which place:')
                    continue
                break
            count+=1
    def cpu():                  #The function play with cpu 
        global count
        while count<6:
            position(dicti)
            print(inp1,"'s choice ",list1[0],'.move to which place (numbers in between 1-9):')
            move=input()
            if(dicti[move]==' '):
                dicti[move]=list1[0]
                check()
            else:
                print('this place is already filled\nmove to which place:')
                continue
            while count<5:
                position(dicti)
                move=random.choice(list2)
                if(dicti[move]==' '):
                    dicti[move]=list1[1]
                    check()
                else:
                    continue
                break
            count+=1
    def restart1():              #The function if we want repeat the game
        global count
        l=input('Restart the game[y/n]:')
        if(l=='y'):
            for key in dicti:
                dicti[key]=' '
            count=0
            print('\t  Score')
            print('  ',inp1,':',a,'\t',inp2,':',b)
            if(inp=='1'):
                dual()
            else:
                cpu()
        if(l=='n'):
            print('\n\n  Score\n',a,'|',b)
            sys.quit()
    def check():                 #function with check the game each time who is win 
        global a,b
        if(dicti['1']==list1[0] and dicti['2']==list1[0] and dicti['3']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['1']==list1[0] and dicti['4']==list1[0] and dicti['7']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['1']==list1[0] and dicti['5']==list1[0] and dicti['9']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['2']==list1[0] and dicti['5']==list1[0] and dicti['8']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['3']==list1[0] and dicti['6']==list1[0] and dicti['9']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['3']==list1[0] and dicti['5']==list1[0] and dicti['7']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['5']==list1[0] and dicti['4']==list1[0] and dicti['6']==list1[0]):
            print(inp1,'WON')
            restart1()
        elif(dicti['7']==list1[0] and dicti['8']==list1[0] and dicti['9']==list1[0]):
            print(inp1,'WON')
            a+=1
            restart1()
        elif(dicti['1']==list1[1] and dicti['2']==list1[1] and dicti['3']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['6']==list1[1] and dicti['4']==list1[1] and dicti['5']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['8']==list1[1] and dicti['9']==list1[1] and dicti['7']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['1']==list1[1] and dicti['4']==list1[1] and dicti['7']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['2']==list1[1] and dicti['5']==list1[1] and dicti['8']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['3']==list1[1] and dicti['6']==list1[1] and dicti['9']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['1']==list1[1] and dicti['5']==list1[1] and dicti['9']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        elif(dicti['3']==list1[1] and dicti['5']==list1[1] and dicti['7']==list1[1]):
            print(inp2,'WON')
            b+=1
            restart1()
        else:
            if(count==4):
                print('DRAW')
                restart1()

    inp=input('1:Dual play\n2:Play with cpu\n3:help\n')     #choose the game mode like single play or dual play
    if(inp=='1'):
        inp1=input('Enter player 1 name:')
        inp2=input('Enter player 2 name:')
        print('\t  Score')
        print('  ',inp1,':',a,'\t',inp2,':',b)
        print(dicti['1'])
        dual()
    elif(inp=='2'):
        inp1=input('Enter player 1 name:')
        inp2='CPU'
        print('\t  Score')
        print('  ',inp1,':',a,'\t',inp2,':',b)
        cpu()
    else:
        print('This is a tic-tac-toe game')
except Exception as a:
    print("\n\nThankYou")
# Out:
# 1:Dual play
# 2:Play with cpu
# 3:help
# 1
# Enter player 1 name:faga
# Enter player 2 name:iau
# 	  Score
#    faga : 0 	 iau : 0
#
#    |  |
#  --+--+--
#    |  |
#  --+--+--
#    |  |
# faga 's choice  X .move to which place(numbers in between 1-9):
# 1
#   X|  |
#  --+--+--
#    |  |
#  --+--+--
#    |  |
# iau 's choice  O .move to which place(numbers in between 1-9):
# 4
#   X|  |
#  --+--+--
#   O|  |
#  --+--+--
#    |  |
# faga 's choice  X .move to which place(numbers in between 1-9):
# 2
#   X| X|
#  --+--+--
#   O|  |
#  --+--+--
#    |  |
# iau 's choice  O .move to which place(numbers in between 1-9):
# 5
#   X| X|
#  --+--+--
#   O| O|
#  --+--+--
#    |  |
# faga 's choice  X .move to which place(numbers in between 1-9):
# 3
# faga WON
# Restart the game[y/n]:n
#
#
#   Score
#  1 | 0
#
#
# ThankYou
